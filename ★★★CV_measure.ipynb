# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress

# Device parameters: change these values and all Vth / SS / mobility results update together

file_path = 'igzo_leakage_data_260626/CV_meas/'+'[#2_unit_80C_R0]C-V with freq 1st [-3.00;0.05;3.00]~[0.03,CPD]-0.txt'
with open(file_path, 'r', encoding='utf-8') as f:
    lines = f.readlines()

df = pd.read_csv(file_path, sep='\t', header=0)


df.columns = df.columns.str.strip()

print(df.head(10))
# Out:
#       V        1.000k       10.000k      100.000k        1.000M
# 0 -3.00  4.466560e-13  3.882910e-13  3.948040e-13  3.993990e-13
# 1 -2.95  4.133750e-13  3.853850e-13  3.958130e-13  4.000450e-13
# 2 -2.90  4.962620e-13  3.882690e-13  3.963970e-13  4.011250e-13
# 3 -2.85  4.172960e-13  3.913270e-13  3.971760e-13  4.016610e-13
# 4 -2.80  3.679720e-13  3.942040e-13  3.969840e-13  4.017690e-13
# 5 -2.75  4.072410e-13  3.904000e-13  3.976200e-13  4.024370e-13
# 6 -2.70  4.808150e-13  3.868690e-13  3.987420e-13  4.035560e-13
# 7 -2.65  4.054440e-13  3.885580e-13  3.990350e-13  4.040340e-13
# 8 -2.60  4.437070e-13  3.833260e-13  4.000570e-13  4.040900e-13
# 9 -2.55  4.276850e-13  3.895130e-13  4.003810e-13  4.047280e-13

# %%
freq_cols = ['1.000k', '10.000k', '100.000k', '1.000M']
labels    = ['1 kHz', '10 kHz', '100 kHz', '1 MHz']
colors    = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red']

fig, ax = plt.subplots()

for col, label, color in zip(freq_cols, labels, colors):
    ax.plot(df['V'], df[col] * 1e12, label=label, color=color, lw=1.5)

ax.set_xlabel('Voltage (V)', fontsize=12)
ax.set_ylabel('Capacitance (pF)', fontsize=12)
ax.set_title('C-V Characteristics', fontsize=13)
ax.legend(bbox_to_anchor=(1, 1),title='Frequency', fontsize=10)
ax.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
